# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

cwd = os.getcwd()
code_dir = os.path.dirname(cwd)
sys.path.append(code_dir)

from lib.directories import *
from lib.plotting import *

DATASET = "FSD50K.eval_audio"

# %%
models = [
        ("fs-essentia-extractor_legacy",
         "PCA_100",
        "nn"
        ),
        ("audioset-yamnet-1", 
        "Agg_mean-PCA_100-Norm_True", 
        "nn"
        ),
        ("audioset-vggish-3", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
        ("fsd-sinet-vgg41-tlpf-1", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
        ("fsd-sinet-vgg42-tlpf-1", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
        ("openl3-env-mel256-emb512-3", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
]

# %% [markdown]
# ## Compare Best Models

# %% [markdown]
# ### Micro and macro

# %%
save = False
save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
plot_map_comparisons_multimodel(models, "micro", save_fig=save, save_dir=save_dir)
plot_map_comparisons_multimodel(models, "macro", save_fig=save, save_dir=save_dir)

# %% [markdown]
# ### Family-based mAP@15 Comparisons

# %%
save = True
save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
plot_family_map_comparisons_multimodel(models, save_fig=save, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/family_based_mAP@15-comparison.png

# %% [markdown]
# ### MR1

# %%
save = False
save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
plot_mr1_comparisons_multimodel(models, "micro", save_fig=save, save_dir=save_dir)
plot_mr1_comparisons_multimodel(models, "macro", save_fig=save, save_dir=save_dir)

# %%
save = True
plot_family_mr1_comparisons_multimodel(models, save_fig=save, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/family_based_MR1-comparison.png

# %% [markdown]
# ## Single Model Plots

# %% [markdown]
# ### Label-Family

# %%
save = False
for model in models:
    save_dir = os.path.join(FIGURES_DIR, "best_embeddings", model[0], model[1], model[2])
    #plot_label_based_map_at_15(model, save_fig=save, save_dir=save_dir)
    plot_family_based_map_at_15(model, save_fig=save, save_dir=save_dir)

# %% [markdown]
# ### Label

# %%
save = False
for model in models:
    save_dir = os.path.join(FIGURES_DIR, "best_embeddings", model[0], model[1], model[2])
    plot_label_based_map_at_15(model, save_fig=save, save_dir=save_dir)

# %% [markdown]
# ### Micro and Macro mAP@15 for all variations

# %%
plot_map_at_15_comparisons(models[2][0], "micro", presentation_mode=True)
plot_map_at_15_comparisons(models[2][0], "macro", presentation_mode=True)

# %% [markdown]
# ### PCA Comparisons

# %%
save = True
save_dir = os.path.join(FIGURES_DIR, "best_embeddings", "PCA_components")
plot_macro_map_at_15_PCA_comparisons(("fs-essentia-extractor_legacy", "", "", "nn"), save_fig=save, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("fsd-sinet-vgg41-tlpf-1", "mean", "True", "nn"), save_fig=save, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("fsd-sinet-vgg42-tlpf-1", "mean", "True", "nn"), save_fig=save, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("audioset-yamnet-1", "mean", "True", "nn"), save_fig=save, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/fs-essentia-extractor_legacy---nn-macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/fsd-sinet-vgg41-tlpf-1-mean-True-nn-macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/fsd-sinet-vgg42-tlpf-1-mean-True-nn-macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/audioset-yamnet-1-mean-True-nn-macro_map@15-PCA_comparisons.png
