# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

cwd = os.getcwd()
code_dir = os.path.dirname(cwd)
sys.path.append(code_dir)

from lib.directories import *
from lib.plotting import *

DATASET = "FSD50K.eval_audio"

# %%
search = "nn"
suffix_agg = "Agg_mean-PCA_100-Norm_True"
suffix_no_agg = "Agg_none-PCA_100-Norm_True"

models = [
        ("fs-essentia-extractor_legacy",
         "PCA_100",
        search
        ),
        ("audioset-yamnet-1", 
        suffix_agg, 
        search
        ),
        ("audioset-vggish-3", 
        suffix_agg,
        search
        ),
        # ("fsd-sinet-vgg41-tlpf-1", 
        # suffix_agg,
        # search
        # ),
        ("fsd-sinet-vgg42-tlpf-1", 
        suffix_agg,
        search
        ),
        ("openl3-env-mel256-emb512-3", 
        suffix_agg,
        search
        ),
        ("clap-630k-fusion-best",
        suffix_no_agg,
        search
        ),
        ("imagebind_huge",
        suffix_no_agg,
        search
        ),
        ("AudioCLIP-Full-Training",
        suffix_no_agg,
        search),
        ("Wav2CLIP",
        suffix_no_agg,
        search),        
]

# %% [markdown]
# ## Compare Best Models

# %% [markdown]
# ### MAP

# %% [markdown]
# #### Micro and macro

# %%
save = True
save_dir = os.path.join(FIGURES_DIR, "thesis", "best_embeddings")
#save_dir = os.path.join(FIGURES_DIR, "evaluation_results", "best_embeddings")
plot_map_comparisons_multimodel(models, "micro", use_fig_name=False, legend=False, save_fig=save, save_dir=save_dir)
plot_map_comparisons_multimodel(models, "macro", use_fig_name=False, legend=False, save_fig=save, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/thesis/best_embeddings/best_embeddings-micro_mAP@15-comparison.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/thesis/best_embeddings/best_embeddings-macro_mAP@15-comparison.png

# %% [markdown]
# #### Family-based mAP@15 Comparisons

# %%
save = True
save_dir = os.path.join(FIGURES_DIR, "thesis", "best_embeddings")
#save_dir = os.path.join(FIGURES_DIR, "evaluation_results", "best_embeddings")
plot_family_map_comparisons_multimodel(models, legend=False, save_fig=save, save_dir=save_dir)
# Out:
# [autoreload of lib.plotting.multi_model_plots failed: Traceback (most recent call last):
#   File "/home/roguz/freesound/freesound-perceptual_similarity/ps/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 273, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/roguz/freesound/freesound-perceptual_similarity/ps/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 471, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 879, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1017, in get_code
#   File "<frozen importlib._bootstrap_external>", line 947, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ...

# %% [markdown]
# ### MR1

# %%
save = True
# save_dir = os.path.join(FIGURES_DIR, "presentation")
save_dir = os.path.join(FIGURES_DIR, "evaluation_results", "best_embeddings")
plot_mr1_comparisons_multimodel(models, "micro", save_fig=save, save_dir=save_dir)
plot_mr1_comparisons_multimodel(models, "macro", save_fig=save, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/evaluation_results/best_embeddings/best_embeddings-micro_MR1-comparison.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/evaluation_results/best_embeddings/best_embeddings-macro_MR1-comparison.png

# %%
save = False
#save_dir = os.path.join(FIGURES_DIR, "presentation")
save_dir = os.path.join(FIGURES_DIR, "evaluation_results", "best_embeddings")
plot_family_mr1_comparisons_multimodel(models, save_fig=save, save_dir=save_dir)

# %% [markdown]
# ### Some PCA Reduction

# %%
_models = [
        ("fs-essentia-extractor_legacy",
         "",
         "",
        "nn"
        ),
        ("audioset-yamnet-1", 
        "mean",
        "True", 
        "nn"
        ),
        ("fsd-sinet-vgg41-tlpf-1", 
        "mean",
        "True",
        "nn"
        ),
        ("fsd-sinet-vgg42-tlpf-1", 
        "mean",
        "True",
        "nn"
        ),
]
save = True
save_dir = os.path.join(FIGURES_DIR, "presentation", "PCA_components")
plot_macro_map_pca_comparisons_multimodel(_models, save_fig=save, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/PCA_components/macro_map@15-PCA_comparisons-multi_models.png

# %% [markdown]
# ## Single Model Plots

# %% [markdown]
# ### Label-Family

# %%
save = False
#save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
for model in models:
    print(model)
    if "imagebind" not in model[0]:
        continue
    save_dir = os.path.join(FIGURES_DIR, "best_embeddings", model[0], model[1], model[2])
    #plot_label_based_map_at_15(model, save_fig=save, save_dir=save_dir)
    plot_family_based_map_at_15(model, save_fig=save, save_dir=save_dir)
# Out:
# ('fs-essentia-extractor_legacy', 'PCA_100', 'nn')
# ('audioset-yamnet-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('audioset-vggish-3', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('fsd-sinet-vgg41-tlpf-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('fsd-sinet-vgg42-tlpf-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('openl3-env-mel256-emb512-3', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('clap-630k-fusion-best', 'Agg_none-PCA_100-Norm_True', 'nn')
# ('imagebind_huge', 'Agg_none-PCA_100-Norm_True', 'nn')

# %% [markdown]
# ### Label

# %%
save = True
for model in models:
    print(model)
    if "imagebind" not in model[0]:
        continue
    save_dir = os.path.join(FIGURES_DIR, "best_embeddings", model[0], model[1], model[2])
    # save_dir = os.path.join(FIGURES_DIR, "presentation", model[0], model[1], model[2])
    plot_label_based_map_at_15(model, save_fig=save, save_dir=save_dir)
# Out:
# ('fs-essentia-extractor_legacy', 'PCA_100', 'nn')
# ('audioset-yamnet-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('audioset-vggish-3', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('fsd-sinet-vgg41-tlpf-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('fsd-sinet-vgg42-tlpf-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('openl3-env-mel256-emb512-3', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ('clap-630k-fusion-best', 'Agg_none-PCA_100-Norm_True', 'nn')
# ('imagebind_huge', 'Agg_none-PCA_100-Norm_True', 'nn')
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/imagebind_huge/Agg_none-PCA_100-Norm_True/nn/label_based_mAP@15.png

# %% [markdown]
# ### Micro and Macro mAP@15 for all variations

# %%
save = True
#save_dir = os.path.join(FIGURES_DIR, "best_embeddings", model[0], model[1], model[2])
for model in models:
    save_dir = os.path.join(FIGURES_DIR, "presentation", model[0], model[1], model[2])
    plot_map_at_15_comparisons(model[0], "micro", presentation_mode=True, save_fig=save, save_dir=save_dir)
    plot_map_at_15_comparisons(model[0], "macro", presentation_mode=True, save_fig=save, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/fs-essentia-extractor_legacy/PCA_100/nn/micro_mAP@15-comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/fs-essentia-extractor_legacy/PCA_100/nn/macro_map@15-comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/audioset-yamnet-1/Agg_mean-PCA_100-Norm_True/nn/micro_mAP@15-comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/audioset-yamnet-1/Agg_mean-PCA_100-Norm_True/nn/macro_map@15-comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/audioset-vggish-3/Agg_mean-PCA_100-Norm_True/nn/micro_mAP@15-comparisons.png
# ...

# %% [markdown]
# ### PCA Comparisons

# %%
save = True
#save_dir = os.path.join(FIGURES_DIR, "best_embeddings", "PCA_components")
save_dir = os.path.join(FIGURES_DIR, "presentation", "PCA_components")
plot_macro_map_at_15_PCA_comparisons(("fs-essentia-extractor_legacy", "", "", "nn"), save_fig=save, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("fsd-sinet-vgg41-tlpf-1", "mean", "True", "nn"), save_fig=save, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("fsd-sinet-vgg42-tlpf-1", "mean", "True", "nn"), save_fig=save, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("audioset-yamnet-1", "mean", "True", "nn"), save_fig=save, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/PCA_components/fs-essentia-extractor_legacy---nn-macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/PCA_components/fsd-sinet-vgg41-tlpf-1-mean-True-nn-macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/PCA_components/fsd-sinet-vgg42-tlpf-1-mean-True-nn-macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/PCA_components/audioset-yamnet-1-mean-True-nn-macro_map@15-PCA_comparisons.png
