# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

cwd = os.getcwd()
code_dir = os.path.dirname(cwd)
sys.path.append(code_dir)

from lib.directories import *
from lib.plotting import *

DATASET = "FSD50K.eval_audio"

# %%
save_dir_comparison = os.path.join(FIGURES_DIR, "thesis", "comparison")
save_dir_single = os.path.join(FIGURES_DIR, "thesis", "single_models")

search = "nn"
suffix_agg = "Agg_mean-PCA_100-Norm_True"
suffix_no_agg = "Agg_none-PCA_100-Norm_True"

models = [
        ("fs-essentia-extractor_legacy",
         "PCA_100",
        search
        ),
        ("audioset-yamnet-1", 
        suffix_agg, 
        search
        ),
        ("audioset-vggish-3", 
        suffix_agg,
        search
        ),
        ("fsd-sinet-vgg42-tlpf-1", 
        suffix_agg,
        search
        ),
        ("openl3-env-mel256-emb512-3", 
        suffix_agg,
        search
        ),
        ("clap-630k-fusion-best",
        suffix_no_agg,
        search
        ),
        ("imagebind_huge",
        suffix_no_agg,
        search
        ),
        ("AudioCLIP-Full-Training",
        suffix_no_agg,
        search
        ),
        ("Wav2CLIP",
        suffix_no_agg,
        search
        ),        
]


SSL_MODELS = [
        "openl3-env-mel256-emb512-3",
        "clap-630k-fusion-best",
        "imagebind_huge",
        "AudioCLIP-Full-Training",
        "Wav2CLIP",
]

# %% [markdown]
# ## Compare Best Models

# %% [markdown]
# ### MAP

# %% [markdown]
# #### Micro, Macro

# %% [markdown]
# ##### 15, 150 Joint

# %%
plot_map_15_and_150_comparisons_multimodel(models, "macro", use_fig_name=False, legend=True, save_fig=True, save_dir=save_dir_comparison)
# Out:
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/comparison/macro_mAP@15_mAP@150-comparison.png

# %% [markdown]
# ##### 15, 150 Separate

# %%
save = True

for N in [15, 150]:
    plot_map_comparisons_multimodel(models, "macro", N=N, use_fig_name=False, legend=False, save_fig=save, save_dir=save_dir_comparison)
# Out:
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/comparison/macro_mAP@15-comparison.png
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/comparison/macro_mAP@150-comparison.png

# %% [markdown]
# #### Family-based mAP@15 Comparisons

# %%
save = True
plot_family_map_comparisons_multimodel(models, legend=False, use_fig_name=False, save_fig=save, save_dir=save_dir_comparison)
# Out:
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/comparison/family_based_mAP@15-comparison.png

# %% [markdown]
# ### MR1

# %%
save = True
plot_mr1_comparisons_multimodel(models, "macro", legend=True, use_fig_name=False, save_fig=True, save_dir=save_dir_comparison)
# Out:
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/comparison/macro_MR1-comparison.png

# %%
plot_family_mr1_comparisons_multimodel(models, legend=False, use_fig_name=False, save_fig=save, save_dir=save_dir_comparison)
# Out:
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/comparison/family_based_MR1-comparison.png

# %% [markdown]
# ### Some PCA Reduction

# %%
_models = [
        ("fs-essentia-extractor_legacy",
         "",
         "",
        "nn"
        ),
        ("audioset-yamnet-1", 
        "mean",
        "True", 
        "nn"
        ),
        ("fsd-sinet-vgg42-tlpf-1", 
        "mean",
        "True",
        "nn"
        ),
]
#save = True
#save_dir = os.path.join(FIGURES_DIR, "presentation", "PCA_components")
plot_macro_map_pca_comparisons_multimodel(_models, save_fig=save, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/presentation/PCA_components/macro_map@15-PCA_comparisons-multi_models.png

# %% [markdown]
# ## Single Model Plots

# %% [markdown]
# ### Sound Family

# %% [markdown]
# ##### 15

# %%
for model in models:
    print(model)
    plot_map_at_N_for_families(model, N=15, use_fig_name=False, save_fig=True, save_dir=os.path.join(save_dir_single, model[0]))
# Out:
# ('fs-essentia-extractor_legacy', 'PCA_100', 'nn')
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/thesis/single_models/fs-essentia-extractor_legacy/family_based_mAP@15.png
# ('audioset-yamnet-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/thesis/single_models/audioset-yamnet-1/family_based_mAP@15.png
# ('audioset-vggish-3', 'Agg_mean-PCA_100-Norm_True', 'nn')
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/thesis/single_models/audioset-vggish-3/family_based_mAP@15.png
# ('fsd-sinet-vgg42-tlpf-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/thesis/single_models/fsd-sinet-vgg42-tlpf-1/family_based_mAP@15.png
# ('openl3-env-mel256-emb512-3', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ...

# %% [markdown]
# ##### 15-150

# %%
for model in models:
    plot_map_at_15_150_for_families(model, use_fig_name=False, save_fig=True, save_dir=os.path.join(save_dir_single, model[0]))
# Out:
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/fs-essentia-extractor_legacy/family_based_mAP@15_mAP@150150.png
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/audioset-yamnet-1/family_based_mAP@15_mAP@150150.png
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/audioset-vggish-3/family_based_mAP@15_mAP@150150.png
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/fsd-sinet-vgg42-tlpf-1/family_based_mAP@15_mAP@150150.png
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/openl3-env-mel256-emb512-3/family_based_mAP@15_mAP@150150.png
# ...

# %% [markdown]
# ### Label

# %%
save = True
for model in models:
    print(model)
    plot_map_at_15_for_all_labels(model, use_fig_name=False, save_fig=save, save_dir=os.path.join(save_dir_single, model[0]))
# Out:
# ('fs-essentia-extractor_legacy', 'PCA_100', 'nn')
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/fs-essentia-extractor_legacy/label_based_mAP@15.png
# ('audioset-yamnet-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/audioset-yamnet-1/label_based_mAP@15.png
# ('audioset-vggish-3', 'Agg_mean-PCA_100-Norm_True', 'nn')
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/audioset-vggish-3/label_based_mAP@15.png
# ('fsd-sinet-vgg42-tlpf-1', 'Agg_mean-PCA_100-Norm_True', 'nn')
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/fsd-sinet-vgg42-tlpf-1/label_based_mAP@15.png
# ('openl3-env-mel256-emb512-3', 'Agg_mean-PCA_100-Norm_True', 'nn')
# ...

# %% [markdown]
# ### Total-composite for All variations

# %%
save = True
for model in models:

    if model[0] in ["fs-essentia-extractor_legacy"]:
        map_precision = 5
    elif model[0] == "clap-630k-fusion-best":
        map_precision = 4
    elif model[0] in ["imagebind_huge", "openl3-env-mel256-emb512-3", "AudioCLIP-Full-Training"]:
        map_precision = 3
    else:
        map_precision = 2
    print(model[0])
    plot_map_at_15_comparisons(model[0], "macro", map_precision=map_precision, use_fig_name=False, presentation_mode=True, save_fig=save, save_dir=os.path.join(save_dir_single, model[0]))
# Out:
# fs-essentia-extractor_legacy
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/fs-essentia-extractor_legacy/macro_map@15-comparisons.png
# audioset-yamnet-1
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/audioset-yamnet-1/macro_map@15-comparisons.png
# audioset-vggish-3
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/audioset-vggish-3/macro_map@15-comparisons.png
# fsd-sinet-vgg42-tlpf-1
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/fsd-sinet-vgg42-tlpf-1/macro_map@15-comparisons.png
# openl3-env-mel256-emb512-3
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/openl3-env-mel256-emb512-3/macro_map@15-comparisons.png
# clap-630k-fusion-best
# ...

# %% [markdown]
# ### PCA Comparisons

# %%
save = True
pca_models = [
    ("fs-essentia-extractor_legacy", "", "", "nn"),
    ("fsd-sinet-vgg42-tlpf-1", "mean", "True", "nn"),
    ("clap-630k-fusion-best", "none", "True", "nn")
    #("audioset-yamnet-1", "mean", "True", "nn"),
]
for model in pca_models:
    plot_macro_map_at_15_PCA_comparisons(model, 
                                        use_fig_name=False,
                                        save_fig=save, 
                                        save_dir=os.path.join(save_dir_single, model[0]),
                                        )
# Out:
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/fs-essentia-extractor_legacy/macro_map@15-PCA_comparisons.png
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/fsd-sinet-vgg42-tlpf-1/macro_map@15-PCA_comparisons.png
# Saving figure to /home/oguz/Desktop/MastersThesis/freesound-sound_similarity/data/figures/thesis/single_models/clap-630k-fusion-best/macro_map@15-PCA_comparisons.png
