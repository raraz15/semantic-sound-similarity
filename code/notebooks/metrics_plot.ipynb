# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

cwd = os.getcwd()
code_dir = os.path.dirname(cwd)
sys.path.append(code_dir)

from lib.directories import *
from lib.plotting import *

DATASET = "FSD50K.eval_audio"

# %% [markdown]
# ## mAP@15 - Compare Multiple Models

# %%
models = [
        ("fs-essentia-extractor_legacy",
         "PCA_100",
        "nn"
        ),
        ("audioset-yamnet-1", 
        "Agg_mean-PCA_100-Norm_True", 
        "nn"
        ),
        ("audioset-vggish-3", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
        ("fsd-sinet-vgg41-tlpf-1", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
        ("fsd-sinet-vgg42-tlpf-1", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
        ("openl3-env-mel256-emb512-3", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
]

# %% [markdown]
# ### Micro and macro

# %%
save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
plot_map_comparisons_multimodel(models, "micro", save_fig=True, save_dir=save_dir)
plot_map_comparisons_multimodel(models, "macro", save_fig=True, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/best_embeddings-micro_mAP@15-comparison.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/best_embeddings-macro_mAP@15-comparison.png

# %% [markdown]
# ### Compare Versions of a Model

# %%
for model in models:
    save_dir = os.path.join(FIGURES_DIR, "best_embeddings", model[0], model[1], model[2])
    plot_label_based_map_at_15(model, save_fig=True, save_dir=save_dir)
    plot_family_based_map_at_15(model, save_fig=True, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/fs-essentia-extractor_legacy/PCA_100/nn/label_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/fs-essentia-extractor_legacy/PCA_100/nn/family_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/audioset-yamnet-1/Agg_mean-PCA_100-Norm_True/nn/label_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/audioset-yamnet-1/Agg_mean-PCA_100-Norm_True/nn/family_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/audioset-vggish-3/Agg_mean-PCA_100-Norm_True/nn/label_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/audioset-vggish-3/Agg_mean-PCA_100-Norm_True/nn/family_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/fsd-sinet-vgg41-tlpf-1/Agg_mean-PCA_100-Norm_True/nn/label_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/fsd-sinet-vgg41-tlpf-1/Agg_mean-PCA_100-Norm_True/nn/family_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/fsd-sinet-vgg42-tlpf-1/Agg_mean-PCA_100-Norm_True/nn/label_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/fsd-sinet-vgg42-tlpf-1/Agg_mean-PCA_100-Norm_True/nn/family_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/openl3-env-mel256-emb512-3/Agg_mean-PCA_100-Norm_True/nn/label_based_mAP@15.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/openl3-env-mel256-emb512-3/Agg_mean-PCA_100-Norm_True/nn/family_based_mAP@15.png

# %% [markdown]
# ### Family-based mAP@15

# %%
save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
plot_family_map_comparisons_multimodel(models, save_fig=True, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/family_based_mAP@15-comparison.png

# %% [markdown]
# ### PCA Comparisons

# %%
save_dir = os.path.join(FIGURES_DIR, "best_embeddings", "PCA_components")
plot_macro_map_at_15_PCA_comparisons(("fs-essentia-extractor_legacy", "", "", "nn"), save_fig=True, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("fsd-sinet-vgg41-tlpf-1", "mean", "True", "nn"), save_fig=True, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("fsd-sinet-vgg42-tlpf-1", "mean", "True", "nn"), save_fig=True, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("audioset-yamnet-1", "mean", "True", "nn"), save_fig=True, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/macro_map@15-PCA_comparisons.png

# %% [markdown]
# ## MR1

# %%
save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
plot_mr1_comparisons_multimodel(models, "micro", save_fig=True, save_dir=save_dir)
plot_mr1_comparisons_multimodel(models, "macro", save_fig=True, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/best_embeddings-micro_MR1-comparison.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/best_embeddings-macro_MR1-comparison.png

# %%
plot_family_mr1_comparisons_multimodel(models, save_fig=True, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/family_based_MR1-comparison.png
