# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

cwd = os.getcwd()
code_dir = os.path.dirname(cwd)
sys.path.append(code_dir)

from lib.directories import *
from lib.plotting import *

DATASET = "FSD50K.eval_audio"

# %% [markdown]
# ## mAP@15 - Compare Multiple Models

# %%
models = [
        ("fs-essentia-extractor_legacy",
         "PCA_100",
        "nn"
        ),
        ("audioset-yamnet-1", 
        "Agg_mean-PCA_100-Norm_True", 
        "nn"
        ),
        ("audioset-vggish-3", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
        ("fsd-sinet-vgg41-tlpf-1", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
        ("fsd-sinet-vgg42-tlpf-1", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
        ("openl3-env-mel256-emb512-3", 
        "Agg_mean-PCA_100-Norm_True",
        "nn"
        ),
]

# %% [markdown]
# ### Micro and macro

# %%
save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
plot_map_comparisons_multimodel(models, "micro", save_fig=False, save_dir=save_dir)
plot_map_comparisons_multimodel(models, "macro", save_fig=False, save_dir=save_dir)

# %% [markdown]
# ### Compare Versions of a Model

# %%
for model in models:
    save_dir = os.path.join(FIGURES_DIR, "best_embeddings", model[0], model[1], model[2])
    # plot_label_based_map_at_15(model, save_fig=False, save_dir=save_dir)
    # plot_family_based_map_at_15(model, save_fig=False, save_dir=save_dir)

# %% [markdown]
# ### Family-based mAP@15

# %%
save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
plot_family_map_comparisons_multimodel(models, save_fig=False, save_dir=save_dir)

# %% [markdown]
# ### PCA Comparisons

# %%
save_dir = os.path.join(FIGURES_DIR, "best_embeddings", "PCA_components")
plot_macro_map_at_15_PCA_comparisons(("fs-essentia-extractor_legacy", "", "", "nn"), save_fig=True, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("fsd-sinet-vgg41-tlpf-1", "mean", "True", "nn"), save_fig=True, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("fsd-sinet-vgg42-tlpf-1", "mean", "True", "nn"), save_fig=True, save_dir=save_dir)
plot_macro_map_at_15_PCA_comparisons(("audioset-yamnet-1", "mean", "True", "nn"), save_fig=True, save_dir=save_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/macro_map@15-PCA_comparisons.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings/PCA_components/macro_map@15-PCA_comparisons.png

# %% [markdown]
# ## MR1

# %%
save_dir = os.path.join(FIGURES_DIR, "best_embeddings")
plot_mr1_comparisons_multimodel(models, "micro", save_fig=False, save_dir=save_dir)
plot_mr1_comparisons_multimodel(models, "macro", save_fig=False, save_dir=save_dir)

# %%
plot_family_mr1_comparisons_multimodel(models, save_fig=False, save_dir=save_dir)

# %%
models = [
        ("fs-essentia-extractor_legacy-PCA_100",
            "nn"
        ),
        ("audioset-yamnet-1-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
        ("audioset-vggish-3-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg41-tlpf-1-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
]

plot_mr1_comparisons_single_variation(models=models, eval_dir=eval_dir, save_fig=True, save_dir=figures_dir)

# %% [markdown]
# ## MAP@K (old)

# %% [markdown]
# ### Micro MAP

# %%
plot_map_at_all_k(model = "fs-essentia-extractor_legacy", eval_dir=eval_dir)

# %%
plot_map_at_all_k(model = "audioset-yamnet-1", eval_dir=eval_dir)

# %%
plot_map_at_all_k("fsd-sinet-vgg42-aps-1",
    eval_dir=eval_dir
)

# %%
plot_map("fsd-sinet-vgg41-tlpf-1",
    eval_dir=eval_dir
)

# %%
plot_map("fsd-sinet-vgg42-tlpf_aps-1",
    eval_dir=eval_dir
)

# %%
plot_map("fsd-sinet-vgg42-tlpf-1",
    eval_dir=eval_dir
)

# %%
plot_map_at_15("fsd-sinet-vgg42-tlpf-1", eval_dir=eval_dir)

# %% [markdown]
# ### Macro MAP

# %%
plot_av_label_based_map_at_15("audioset-yamnet-1", eval_dir=eval_dir)

# %%
models = [
        ("fs-essentia-extractor_legacy-PCA_100",
            "nn"
        ),
        ("audioset-yamnet-1-Agg_mean-PCA_200-Norm_True",
            "dot"
        ),
        ("audioset-vggish-3-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg41-tlpf-1-Agg_max-PCA_256-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg42-tlpf-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-tlpf_aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
]

plot_macro_map_comparisons_multimodel(models, eval_dir=eval_dir, save_fig=True, save_dir=figures_dir, fig_name="all_variations-av_label_based_mAP_comparison_k15")

# %%
models = [
        ("fs-essentia-extractor_legacy",
            ['PCA_100', 
            'PCA_200', 
            'PCA_846'],
            "nn"
        ),
        ("audioset-yamnet-1",
            ['Agg_mean-PCA_100-Norm_True', 
            'Agg_mean-PCA_200-Norm_True', 
            'Agg_mean-PCA_1024-Norm_True'],
            "dot"
        ),
        ("audioset-vggish-3",
         ['Agg_mean-PCA_64-Norm_True',
          'Agg_mean-PCA_100-Norm_True',
          'Agg_mean-PCA_128-Norm_True'],
            "dot"
        ),
        ("fsd-sinet-vgg42-tlpf-1",
            ['Agg_mean-PCA_100-Norm_True', 
            'Agg_mean-PCA_200-Norm_True', 
            'Agg_mean-PCA_512-Norm_True'],
            "dot"
        ),
]

plot_map_comparisons(models=models, eval_dir=eval_dir, save_fig=True)

# %% [markdown]
# ### All K

# %%
models = [
        ("fsd-sinet-vgg41-tlpf-1-Agg_max-PCA_256-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg42-tlpf-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-tlpf_aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
]

plot_map_comparisons_single_variation(models=models, eval_dir=eval_dir, save_fig=True, save_dir=figures_dir, fig_name="sinet-all_variations-mAP_comparison_k15")
