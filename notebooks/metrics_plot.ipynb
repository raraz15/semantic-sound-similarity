# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

lib_dir = os.path.dirname(os.getcwd())
sys.path.append(lib_dir)

DATASET = "FSD50K.eval_audio"
data_dir = os.path.join(lib_dir, "data")
eval_dir = os.path.join(data_dir, "evaluation_results")
figures_dir = os.path.join(data_dir, "figures")

from plotting import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## MAP@K

# %% [markdown]
# ### Micro MAP

# %%
plot_map_at_all_k(model = "fs-essentia-extractor_legacy", eval_dir=eval_dir)

# %%
plot_map_at_all_k(model = "audioset-yamnet-1", eval_dir=eval_dir)

# %%
plot_map_at_all_k("fsd-sinet-vgg42-aps-1",
    eval_dir=eval_dir
)

# %%
plot_map("fsd-sinet-vgg41-tlpf-1",
    eval_dir=eval_dir
)

# %%
plot_map("fsd-sinet-vgg42-tlpf_aps-1",
    eval_dir=eval_dir
)

# %%
plot_map("fsd-sinet-vgg42-tlpf-1",
    eval_dir=eval_dir
)

# %%
plot_map_at_15("fsd-sinet-vgg42-tlpf-1", eval_dir=eval_dir)

# %% [markdown]
# ### Macro MAP

# %%
plot_av_label_based_map_at_15("audioset-yamnet-1", eval_dir=eval_dir)

# %%
models = [
        ("fs-essentia-extractor_legacy-PCA_100",
            "nn"
        ),
        ("audioset-yamnet-1-Agg_mean-PCA_200-Norm_True",
            "dot"
        ),
        ("audioset-vggish-3-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg41-tlpf-1-Agg_max-PCA_256-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg42-tlpf-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-tlpf_aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
]

plot_macro_map_comparisons_multimodel(models, eval_dir=eval_dir, save_fig=True, save_dir=figures_dir, fig_name="all_variations-av_label_based_mAP_comparison_k15")
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/all_variations-av_label_based_mAP_comparison_k15.png

# %% [markdown]
# ## Compare Multiple Models

# %% [markdown]
# ### All K

# %%
models = [
        ("fs-essentia-extractor_legacy",
            ['PCA_100', 
            'PCA_200', 
            'PCA_846'],
            "nn"
        ),
        ("audioset-yamnet-1",
            ['Agg_mean-PCA_100-Norm_True', 
            'Agg_mean-PCA_200-Norm_True', 
            'Agg_mean-PCA_1024-Norm_True'],
            "dot"
        ),
        ("audioset-vggish-3",
         ['Agg_mean-PCA_64-Norm_True',
          'Agg_mean-PCA_100-Norm_True',
          'Agg_mean-PCA_128-Norm_True'],
            "dot"
        ),
        ("fsd-sinet-vgg42-tlpf-1",
            ['Agg_mean-PCA_100-Norm_True', 
            'Agg_mean-PCA_200-Norm_True', 
            'Agg_mean-PCA_512-Norm_True'],
            "dot"
        ),
]

plot_map_comparisons(models=models, eval_dir=eval_dir, save_fig=True)
# Out:
# Saving figure to data/figures/fs-essentia-extractor_legacy-audioset-yamnet-1-audioset-vggish-3-fsd-sinet-vgg42-tlpf-1-mAP_comparison.png

# %% [markdown]
# ### K=15

# %%
models = [
        ("fs-essentia-extractor_legacy-PCA_100",
            "nn"
        ),
        ("audioset-yamnet-1-Agg_mean-PCA_200-Norm_True",
            "dot"
        ),
        ("audioset-vggish-3-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg41-tlpf-1-Agg_max-PCA_256-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg42-tlpf-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-tlpf_aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
]

plot_map_comparisons_single_variation(models=models, eval_dir=eval_dir, save_fig=True, save_dir=figures_dir, fig_name="all_variations-mAP_comparison_k15")
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/all_variations-mAP_comparison_k15.png

# %%
models = [
        ("fs-essentia-extractor_legacy-PCA_100",
            "nn"
        ),
        ("audioset-yamnet-1-Agg_mean-PCA_200-Norm_True",
            "dot"
        ),
        ("audioset-vggish-3-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg41-tlpf-1-Agg_max-PCA_256-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg42-tlpf-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-tlpf_aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
]

plot_map_comparisons_single_variation(models=models, eval_dir=eval_dir, save_fig=True, save_dir=figures_dir, fig_name="all_variations-mAP_comparison_k15")
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/all_variations-mAP_comparison_k15.png

# %% [markdown]
# ### Micro and macro

# %%
models = [
        ("fs-essentia-extractor_legacy-PCA_100",
            "nn"
        ),
        ("audioset-yamnet-1-Agg_mean-PCA_200-Norm_True",
            "dot"
        ),
        ("audioset-vggish-3-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg41-tlpf-1-Agg_max-PCA_256-Norm_True",
            "dot"
        ),
        ("openl3-env-mel128-emb512-3-Agg_mean-PCA_512-Norm_True",
            "dot"
        ),
]

plot_micro_map_comparisons_multimodel(models, eval_dir, "FSD50K.eval_audio", save_fig=True, save_dir=figures_dir)
plot_macro_map_comparisons_multimodel(models, eval_dir, "FSD50K.eval_audio", save_fig=True, save_dir=figures_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings-micro_mAP@15-comparison.png
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/best_embeddings-macro_mAP@15-comparison.png

# %%
models = [
        ("fsd-sinet-vgg41-tlpf-1-Agg_max-PCA_256-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg42-tlpf-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-tlpf_aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
        ("fsd-sinet-vgg42-aps-1-Agg_max-PCA_512-Norm_True",
            "dot",
        ),
]

plot_map_comparisons_single_variation(models=models, eval_dir=eval_dir, save_fig=True, save_dir=figures_dir, fig_name="sinet-all_variations-mAP_comparison_k15")
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/sinet-all_variations-mAP_comparison_k15.png

# %% [markdown]
# ## MR1

# %%
plot_mr1("fsd-sinet-vgg42-tlpf-1", eval_dir=eval_dir)

# %%
models = [
        ("fs-essentia-extractor_legacy-PCA_100",
            "nn"
        ),
        ("audioset-yamnet-1-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
        ("audioset-vggish-3-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
        ("fsd-sinet-vgg41-tlpf-1-Agg_mean-PCA_100-Norm_True",
            "dot"
        ),
]

plot_mr1_comparisons_single_variation(models=models, eval_dir=eval_dir, save_fig=True, save_dir=figures_dir)
# Out:
# Saving figure to /home/roguz/freesound/freesound-perceptual_similarity/data/figures/fs-essentia-extractor_legacy-PCA_100-audioset-yamnet-1-Agg_mean-PCA_100-Norm_True-audioset-vggish-3-Agg_mean-PCA_100-Norm_True-fsd-sinet-vgg41-tlpf-1-Agg_mean-PCA_100-Norm_True-MR1_comparison.png
